# %%
import numpy as np

a = np.arange(10)
s = slice(2, 7, 2)
print(a[s])
# Out:
# [2 4 6]

# %%
import numpy as np

a = np.arange(10)
b = a[2:7:2]
print(b)
# Out:
# [2 4 6]

# %%
import numpy as np

a = np.arange(10)
b = a[5]
print(b)
# Out:
# 5

# %%
import numpy as np

a = np.arange(10)
print(a[2:])
# Out:
# [2 3 4 5 6 7 8 9]
